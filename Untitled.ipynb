# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.probability import FreqDist
from nltk.sentiment import SentimentIntensityAnalyzer
import spacy

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\agnih\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\agnih\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\agnih\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\agnih\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 653.6 kB/s eta 0:00:20
#      ---------------------------------------- 0.1/12.8 MB 1.2 MB/s eta 0:00:11
#       --------------------------------------- 0.2/12.8 MB 1.7 MB/s eta 0:00:08
#      - -------------------------------------- 0.4/12.8 MB 2.3 MB/s eta 0:00:06
#      -- ------------------------------------- 0.7/12.8 MB 3.0 MB/s eta 0:00:04
#      --- ------------------------------------ 1.1/12.8 MB 4.2 MB/s eta 0:00:03
#      ------ --------------------------------- 2.1/12.8 MB 6.6 MB/s eta 0:00:02
#      -------- ------------------------------- 2.7/12.8 MB 7.5 MB/s eta 0:00:02
#      ---------- ----------------------------- 3.5/12.8 MB 8.9 MB/s eta 0:00:02
#      ------------- -------------------------- 4.5/12.8 MB 9.8 MB/s eta 0:00:01
#      ---------------- ----------------------- 5.3/12.8 MB 10.6 MB/s eta 0:00:01
#      -------------------- ------------------- 6.7/12.8 MB 12.1 MB/s eta 0:00:01
#      ---------------------- ----------------- 7.1/12.8 MB 12.6 MB/s eta 0:00:01
#      ------------------------- -------------- 8.2/12.8 MB 13.1 MB/s eta 0:00:01
#      --------------------------- ------------ 8.7/12.8 MB 13.6 MB/s eta 0:00:01
#      --------------------------- ------------ 8.7/12.8 MB 13.6 MB/s eta 0:00:01
#      --------------------------------- ----- 11.1/12.8 MB 19.3 MB/s eta 0:00:01
#      --------------------------------------  12.6/12.8 MB 21.1 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 21.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.3)
# Requirement already satisfied: jinja2 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.6)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\agnih\appdata\local\programs\python\python311\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.3)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
nlp=spacy.load('en_core_web_sm')

# %%
df=pd.read_excel('assignment.xlsx')

# %%
df
# Out:
#                                               Article
# 0   Retailers, the makers of foods marketed for we...
# 1   Move over, Ozempic — there’s a new drug in tow...
# 2   Sept 14 (Reuters) - Bristol Myers Squibb (BMY....
# 3   Austin Wolcott was 18 years old and pretty sur...
# 4   Cancer, often referred to as the “emperor of a...
# 5   Nov 28 (Reuters) - The U.S. Food and Drug Admi...
# 6   Nov 21 (Reuters) - BeiGene (6160.HK) said on T...
# 7   Sept 19 (Reuters) - Drugmaker BeiGene (6160.HK...
# 8   BRUKINSA is the first and only BTK inhibitor a...
# 9   Whether you're looking for a quick bite to eat...
# 10  A federal judge in New York has dismissed a la...
# 11  The future of fast food delivery is here.\n\nD...
# 12  Yum Brands topped Wall Street estimates for th...
# 13  If you fancy Taco Bell's Nacho Fries, the fast...
# 14  Taco Bell is serving up its new Toasted Breakf...
# 15  Oct 30 (Reuters) - McDonald's (MCD.N) beat Wal...
# 16  Whether you dip it, drizzle it, or put it on c...
# 17  The parent company of Taco Bell, KFC and Pizza...
# 18  Having announced a collaboration with Nike in ...
# 19  Strava has now made it possible for the Nike R...
# 20  Nike (NYSE:NKE) is the leader when it comes to...
# 21  Oct 23 (Reuters) - Unilever (ULVR.L) and a cha...
# 22  LONDON, Sept 19 (Reuters) - Nestle said on Tue...
# 23  Get Smart About News, modeled on the Sift, is ...
# 24  Editorial Note: Blueprint may earn a commissio...

# %%
def clean_text(text):
    stop_words = set(stopwords.words('english'))
    lemmatizer = WordNetLemmatizer()
    tokens = word_tokenize(text)
    cleaned_tokens = [lemmatizer.lemmatize(token.lower()) for token in tokens if token.isalnum() and token.lower() not in stop_words]
    return " ".join(cleaned_tokens)

# %%
# Summarization Module
def extractive_summarization(text):
    sentences = sent_tokenize(text)
    word_frequencies = FreqDist()
    for sentence in sentences:
        for word in word_tokenize(sentence):
            word_frequencies[word.lower()] += 1
    max_frequency = max(word_frequencies.values())
    for word in word_frequencies.keys():
        word_frequencies[word] = (word_frequencies[word] / max_frequency)
    sentence_scores = {}
    for sentence in sentences:
        for word in word_tokenize(sentence.lower()):
            if word in word_frequencies.keys():
                if len(sentence.split(' ')) < 30:
                    if sentence not in sentence_scores.keys():
                        sentence_scores[sentence] = word_frequencies[word]
                    else:
                        sentence_scores[sentence] += word_frequencies[word]
    summarized_sentences = sorted(sentence_scores, key=sentence_scores.get, reverse=True)[:5]
    return ' '.join(summarized_sentences)

# %%
# Mood Check Module
def get_mood(text):
    sia = SentimentIntensityAnalyzer()
    sentiment_score = sia.polarity_scores(text)
    if sentiment_score['compound'] >= 0.05:
        return "Positive"
    elif sentiment_score['compound'] <= -0.05:
        return "Negative"
    else:
        return "Neutral"

# %%
# Process articles and store results in a DataFrame
results = []
for index, row in df.iterrows():
    article_text = row['Article']
    cleaned_text = clean_text(article_text)
    summary = extractive_summarization(article_text)
    mood = get_mood(article_text)
    results.append({'Article': article_text, 'Cleaned Text': cleaned_text, 'Summary': summary, 'Mood': mood})

# Create DataFrame from results
results_df = pd.DataFrame(results)

# Display DataFrame
print(results_df)
# Out:
#                                               Article  \
# 0   Retailers, the makers of foods marketed for we...
# 1   Move over, Ozempic — there’s a new drug in tow...
# 2   Sept 14 (Reuters) - Bristol Myers Squibb (BMY....
# 3   Austin Wolcott was 18 years old and pretty sur...
# 4   Cancer, often referred to as the “emperor of a...
# 5   Nov 28 (Reuters) - The U.S. Food and Drug Admi...
# 6   Nov 21 (Reuters) - BeiGene (6160.HK) said on T...
# 7   Sept 19 (Reuters) - Drugmaker BeiGene (6160.HK...
# 8   BRUKINSA is the first and only BTK inhibitor a...
# 9   Whether you're looking for a quick bite to eat...
# 10  A federal judge in New York has dismissed a la...
# 11  The future of fast food delivery is here.\n\nD...
# 12  Yum Brands topped Wall Street estimates for th...
# 13  If you fancy Taco Bell's Nacho Fries, the fast...
# 14  Taco Bell is serving up its new Toasted Breakf...
# 15  Oct 30 (Reuters) - McDonald's (MCD.N) beat Wal...
# 16  Whether you dip it, drizzle it, or put it on c...
# 17  The parent company of Taco Bell, KFC and Pizza...
# 18  Having announced a collaboration with Nike in ...
# 19  Strava has now made it possible for the Nike R...
# 20  Nike (NYSE:NKE) is the leader when it comes to...
# 21  Oct 23 (Reuters) - Unilever (ULVR.L) and a cha...
# 22  LONDON, Sept 19 (Reuters) - Nestle said on Tue...
# 23  Get Smart About News, modeled on the Sift, is ...
# 24  Editorial Note: Blueprint may earn a commissio...
#
#                                          Cleaned Text  \
# 0   retailer maker food marketed weight loss type ...
# 1   move ozempic new drug town eli lilly zepbound ...
# 2   sept 14 reuters bristol myers squibb said thur...
# 3   austin wolcott 18 year old pretty sure survive...
# 4   cancer often referred emperor malady unyieldin...
# 5   nov 28 reuters food drug administration fda sa...
# 6   nov 21 reuters beigene said tuesday entered ag...
# 7   sept 19 reuters drugmaker beigene said tuesday...
# 8   brukinsa first btk inhibitor approved follicul...
# 9   whether looking quick bite eat experience quic...
# 10  federal judge new york dismissed lawsuit accus...
# 11  future fast food delivery diner within radius ...
# 12  yum brand topped wall street estimate result w...
# 13  fancy taco bell nacho fry chain two new deal c...
# 14  taco bell serving new toasted breakfast taco g...
# 15  oct 30 reuters mcdonald beat wall street estim...
# 16  whether dip drizzle put chicken nugget french ...
# 17  parent company taco bell kfc pizza hut using a...
# 18  announced collaboration nike may 2023 strava l...
# 19  strava made possible nike run club nrc nike tr...
# 20  nike nyse nke leader come consumer sportswear ...
# 21  oct 23 reuters unilever charity supporting tee...
# 22  london sept 19 reuters nestle said tuesday pic...
# 23  get smart news modeled sift free weekly newsle...
# 24  editorial note blueprint may earn commission a...
#
#                                               Summary      Mood
# 0   “The market potential is very, very significan...  Positive
# 1   Side effects of the weekly injectable include ...  Negative
# 2   The New York-based company has been pressured ...  Negative
# 3   “You read how the drug extended the life of si...  Negative
# 4   This approach, while potentially effective, in...  Negative
# 5   J&J unit Janssen and Legend Biotech's (LEGN.O)...  Negative
# 6                                                      Positive
# 7   The drug is currently under review by the U.S....  Negative
# 8   Because new BTK is continuously synthesized, B...  Positive
# 9   However, some locations may have reduced hours...  Positive
# 10  Gonzalez also said the plaintiff, Justin Chimi...  Negative
# 11  The drone then flies the food to its destinati...  Positive
# 12  Taco Bell’s deals aided a 2% to 3% increase in...  Positive
# 13  The tots come seasoned, with scrambled eggs, a...  Positive
# 14  Toasted Breakfast Tacos, a new menu option, ar...  Positive
# 15  Comparable sales in the United States climbed ...  Positive
# 16  The creators are: @Mr.Eats305, @sharidyonne, @...  Positive
# 17  Brands executives told analysts Wednesday they...  Positive
# 18  Having announced a collaboration with Nike in ...  Positive
# 19  Because Nike Run Club works with many social m...  Positive
# 20  While the company does face some real risks to...  Positive
# 21  Unilever and the I'm Not Done Yet Foundation h...  Negative
# 22  WPP Openmind will coordinate Nestle's marketin...  Positive
# 23  Dietitians are being paid to post videos on Ti...  Positive
# 24  New Wells Fargo customers can earn a $300 bonu...  Positive

# %%
results_df.to_csv('article_analysis_results.csv', index=False)

# %%
df1=pd.read_csv('article_analysis_results.csv')

# %%
df1
# Out:
#                                               Article  \
# 0   Retailers, the makers of foods marketed for we...
# 1   Move over, Ozempic — there’s a new drug in tow...
# 2   Sept 14 (Reuters) - Bristol Myers Squibb (BMY....
# 3   Austin Wolcott was 18 years old and pretty sur...
# 4   Cancer, often referred to as the “emperor of a...
# 5   Nov 28 (Reuters) - The U.S. Food and Drug Admi...
# 6   Nov 21 (Reuters) - BeiGene (6160.HK) said on T...
# 7   Sept 19 (Reuters) - Drugmaker BeiGene (6160.HK...
# 8   BRUKINSA is the first and only BTK inhibitor a...
# 9   Whether you're looking for a quick bite to eat...
# 10  A federal judge in New York has dismissed a la...
# 11  The future of fast food delivery is here.\n\nD...
# 12  Yum Brands topped Wall Street estimates for th...
# 13  If you fancy Taco Bell's Nacho Fries, the fast...
# 14  Taco Bell is serving up its new Toasted Breakf...
# 15  Oct 30 (Reuters) - McDonald's (MCD.N) beat Wal...
# 16  Whether you dip it, drizzle it, or put it on c...
